# %% [markdown]
# ## __Analyse d'une base de données de compagnies aérienne__
# ## ----------------------------------------------------------
#
# ### Brève présentation de notre base de donnée
#
# * **Satisfaction :** Satisfaction du passager après le voyage __(_Satisfait_, _Non satisfait_)__
# * **Customer Type :** Type de client __(_Client Fidèle, Client déloyale_)__
# * **Age :** Tranche d'âge des passagers __(_tranches d'ages iront de 0 à 20_)__
# * **Type of Travel :** Type de voyage __(_Voyage d'affaire, voyage personnel_)__
# * **Class :** différentes catégories de clients __(_Eco, Business , Eco Plus_)__
# * **Flight Distance :** Distance du trajet
# * **Seat comfort :**  Siège Confortable
# * **'Departure/Arrival time convenient :** Heure prévus de d'arrivée
# * **Food and drink :** Nourriture et Boissons
# * **Gate location :** Emplacement de la porte
# * **Inflight wifi service :** Service Wifi à bord
# * **Inflight entertainment :**  Divertissement à bord
# * **Online support :** support en ligne
# * **Ease of Online booking :**  Facilité de reservation en ligne
# * **On-board service :** Service à bord
# * **Leg room service :**  Service de chambre pour les jambes
# * **Baggage handling :**  Manutention des bagages
# * **Checkin service :** service d'enregistrement
# * **Cleanliness :**  propreté
# * **Online boarding :** embarquement en ligne
# * **Departure Delay in Minutes :** Départ du voyage en minutes
# * **Arrival Delay in Minutes :** Arrivé du voyage en minutes
#
# Nous ressortons comme principales information de cette base :
# - L'âge des passagers;
# - Les classes de passagers (_Businnes_, _Economique_);
# - L'émotion des passagers (_Satisfait_, _non-satisfait_);
# - Le nombre de bagages transportés;
# - La distance des voyages, ainsi que l'Heure de départ et d'arrivée.
#
# La base de donnée est composé de **129880 lignes** et **22 colonnes**
#
# #### Vous pouvez retrouver cette base de donnée sur kaggle: https://www.kaggle.com/datasets/raminhuseyn/airline-customer-satisfaction
#
# Notre analyse portera sur ces informations phares, ainsi que sur  d'autres non mentionnées plus haut.
#
# ### Notre analyse se déroulera comme suit :
# - lire la base de données (_CSV_), sous la librairie 'Pandas';
# - supprimer les colonnes inutiles à notre analyse ;
# - Nettoyer la base de données ;
# - Calculer le nombre Total des passagers, par classe, et faire une représentation graphique ;
# - Calculer le pourcentage des **passagers satisfaits** et des **passagers non satisfaits**;
# - Calculer la somme des voyageurs par catégorie_sociale (**Enfant, Adolescent,Jeune, Adulte, Âgée**), et faire un  graphique (_Les tranches vont de **0 à 20 ans**_).
#
# ### Quelques calculs supplémentaire :
#
# - Calculer la somme des **Bagages** ;
# - Calculer la somme et la moyenne des **demandes d'aides** ;
# - Calculer la somme  des **Services de vérifications** ;
# - Déterminer **Le plus long et plus court voyage** tout en indicant __l'heure de départ et l'heure d'arrivée__.
# (_Si Possible les transformer en Heures, car elles sont en minutes_)

# %% [markdown]
# ### Lecture et Nettoyage des données

# %%
# Chargement de la librairie Pandas

import pandas as pd
# Out:
# C:\Users\rodri\AppData\Local\Temp\ipykernel_22772\3854334307.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Lecture de la base de données

df = pd.read_csv('Airline_customer_satisfaction.csv')
df
# Out:
#         satisfaction      Customer Type  Age   Type of Travel     Class  \
# 0          satisfied     Loyal Customer   65  Personal Travel       Eco
# 1          satisfied     Loyal Customer   47  Personal Travel  Business
# 2          satisfied     Loyal Customer   15  Personal Travel       Eco
# 3          satisfied     Loyal Customer   60  Personal Travel       Eco
# 4          satisfied     Loyal Customer   70  Personal Travel       Eco
# ...              ...                ...  ...              ...       ...
# 129875     satisfied  disloyal Customer   29  Personal Travel       Eco
# 129876  dissatisfied  disloyal Customer   63  Personal Travel  Business
# 129877  dissatisfied  disloyal Customer   69  Personal Travel       Eco
# 129878  dissatisfied  disloyal Customer   66  Personal Travel       Eco
# 129879  dissatisfied  disloyal Customer   38  Personal Travel       Eco
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# ...

# %%
# Les 20 premières lignes.

df.head(20)
# Out:
#    satisfaction   Customer Type  Age   Type of Travel     Class  \
# 0     satisfied  Loyal Customer   65  Personal Travel       Eco
# 1     satisfied  Loyal Customer   47  Personal Travel  Business
# 2     satisfied  Loyal Customer   15  Personal Travel       Eco
# 3     satisfied  Loyal Customer   60  Personal Travel       Eco
# 4     satisfied  Loyal Customer   70  Personal Travel       Eco
# 5     satisfied  Loyal Customer   30  Personal Travel       Eco
# 6     satisfied  Loyal Customer   66  Personal Travel       Eco
# 7     satisfied  Loyal Customer   10  Personal Travel       Eco
# 8     satisfied  Loyal Customer   56  Personal Travel  Business
# 9     satisfied  Loyal Customer   22  Personal Travel       Eco
# 10    satisfied  Loyal Customer   58  Personal Travel       Eco
# 11    satisfied  Loyal Customer   34  Personal Travel       Eco
# 12    satisfied  Loyal Customer   62  Personal Travel       Eco
# 13    satisfied  Loyal Customer   35  Personal Travel       Eco
# ...

# %%
# Les 20 dernières lignes.

df.tail(20)
# Out:
#         satisfaction      Customer Type  Age   Type of Travel     Class  \
# 129860  dissatisfied  disloyal Customer   43  Personal Travel       Eco
# 129861     satisfied  disloyal Customer   36  Personal Travel       Eco
# 129862     satisfied  disloyal Customer   25  Personal Travel       Eco
# 129863     satisfied  disloyal Customer   52  Personal Travel       Eco
# 129864     satisfied  disloyal Customer   24  Personal Travel       Eco
# 129865     satisfied  disloyal Customer   59  Personal Travel       Eco
# 129866     satisfied  disloyal Customer   18  Personal Travel       Eco
# 129867     satisfied  disloyal Customer   30  Personal Travel       Eco
# 129868     satisfied  disloyal Customer   45  Personal Travel       Eco
# 129869     satisfied  disloyal Customer   55  Personal Travel       Eco
# 129870     satisfied  disloyal Customer   70  Personal Travel       Eco
# 129871     satisfied  disloyal Customer   35  Personal Travel       Eco
# ...

# %%
# Structure du Dataframe.

df.shape
# Out:
# (129880, 22)

# %%
# Les types de données du DataFrame.

df.dtypes
# Out:
# satisfaction                          object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Seat comfort                           int64
# Departure/Arrival time convenient      int64
# Food and drink                         int64
# Gate location                          int64
# Inflight wifi service                  int64
# Inflight entertainment                 int64
# Online support                         int64
# Ease of Online booking                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Cleanliness                            int64
# Online boarding                        int64
# Departure Delay in Minutes             int64
# ...

# %%
# Traitement des valeurs manquantes.
# Vérification des valeurs manquantes
# Méthode N°1 retour de True où False 
df.isnull()

# Ici nous avons False, ce qui indique qu'il n'y a pas de valeurs manquantes
# Out:
#         satisfaction  Customer Type    Age  Type of Travel  Class  \
# 0              False          False  False           False  False
# 1              False          False  False           False  False
# 2              False          False  False           False  False
# 3              False          False  False           False  False
# 4              False          False  False           False  False
# ...              ...            ...    ...             ...    ...
# 129875         False          False  False           False  False
# 129876         False          False  False           False  False
# 129877         False          False  False           False  False
# 129878         False          False  False           False  False
# 129879         False          False  False           False  False
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0                 False         False                              False
# ...

# %%
# Méthode N°2

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   satisfaction                       129880 non-null  object
#  1   Customer Type                      129880 non-null  object
#  2   Age                                129880 non-null  int64
#  3   Type of Travel                     129880 non-null  object
#  4   Class                              129880 non-null  object
#  5   Flight Distance                    129880 non-null  int64
#  6   Seat comfort                       129880 non-null  int64
#  7   Departure/Arrival time convenient  129880 non-null  int64
#  8   Food and drink                     129880 non-null  int64
#  9   Gate location                      129880 non-null  int64
#  10  Inflight wifi service              129880 non-null  int64
# ...

# %%
# Méthode N°3 Faire la somme des valeurs manquantes si elles existent

df.isna().sum()
# Out:
# satisfaction                           0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Food and drink                         0
# Gate location                          0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Online boarding                        0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# dtype: int64

# %%
# Suppression des colonnes dont on n'aura pas besoin dans notre analyse.

col_indices = [6,8,9,10,11,13,14,15,18,19] # Numéro d'index des colonnes à supprimer
col_names = df.columns[col_indices] # Mettre les numéros d'index sous une variable col_namespour avoir la liste des colonnes à supprimer
col_names
# Out:
# Index(['Seat comfort', 'Food and drink', 'Gate location',
#        'Inflight wifi service', 'Inflight entertainment',
#        'Ease of Online booking', 'On-board service', 'Leg room service',
#        'Cleanliness', 'Online boarding'],
#       dtype='object')

# %%
# Suppression des colonnes et nouvelle Base de données avec une nouvelle variable 'travel'

travel = df.drop(columns= col_names)
travel
# Out:
#         satisfaction      Customer Type  Age   Type of Travel     Class  \
# 0          satisfied     Loyal Customer   65  Personal Travel       Eco
# 1          satisfied     Loyal Customer   47  Personal Travel  Business
# 2          satisfied     Loyal Customer   15  Personal Travel       Eco
# 3          satisfied     Loyal Customer   60  Personal Travel       Eco
# 4          satisfied     Loyal Customer   70  Personal Travel       Eco
# ...              ...                ...  ...              ...       ...
# 129875     satisfied  disloyal Customer   29  Personal Travel       Eco
# 129876  dissatisfied  disloyal Customer   63  Personal Travel  Business
# 129877  dissatisfied  disloyal Customer   69  Personal Travel       Eco
# 129878  dissatisfied  disloyal Customer   66  Personal Travel       Eco
# 129879  dissatisfied  disloyal Customer   38  Personal Travel       Eco
#
#         Flight Distance  Departure/Arrival time convenient  Online support  \
# ...

# %%
# Structure de la nouvelle base de données

travel.shape
# Out:
# (129880, 12)

# %%
# Types de données de la nouvelle base 

travel.dtypes
# Out:
# satisfaction                          object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Departure/Arrival time convenient      int64
# Online support                         int64
# Baggage handling                       int64
# Checkin service                        int64
# Departure Delay in Minutes             int64
# Arrival Delay in Minutes             float64
# dtype: object

# %% [markdown]
# ### Calculer le nombre Total des passagers par Types de clients (Eco, Business, Eco plus) et faire une représentation graphique

# %%
# Calcule du nombre Total de client par types (Eco, Business, Eco plus)

total_passenger = travel[['Class']].value_counts().reset_index()
total_passenger
# Out:
#       Class  count
# 0  Business  62160
# 1       Eco  58309
# 2  Eco Plus   9411

# %%
# représentation grapghique

colors = ['black','purple','Green']
total_passenger.plot(kind= 'barh',color=colors,rot= 45, xlabel= 'Effectif par  Classe')

# Ajouter les valeurs sur chaque barre
for i, freq in enumerate(effectif["proportion"]):
    plot.text(i, freq, str(freq), ha='center', va='bottom')
# Out:
# <Axes: xlabel='Effectif par  Classe', ylabel='Class'>

# %% [markdown]
# ### Calcul du taux de satisfaction et de non satisfaction des clients par types _(Eco, Business, Eco Plus_)

# %%
# Selection des personnes satisfatites 

satisfait = travel[travel['satisfaction'] == 'satisfied']
satisfait
# Out:
#        satisfaction      Customer Type  Age   Type of Travel     Class  \
# 0         satisfied     Loyal Customer   65  Personal Travel       Eco
# 1         satisfied     Loyal Customer   47  Personal Travel  Business
# 2         satisfied     Loyal Customer   15  Personal Travel       Eco
# 3         satisfied     Loyal Customer   60  Personal Travel       Eco
# 4         satisfied     Loyal Customer   70  Personal Travel       Eco
# ...             ...                ...  ...              ...       ...
# 129871    satisfied  disloyal Customer   35  Personal Travel       Eco
# 129872    satisfied  disloyal Customer   69  Personal Travel       Eco
# 129873    satisfied  disloyal Customer   63  Personal Travel       Eco
# 129874    satisfied  disloyal Customer   11  Personal Travel       Eco
# 129875    satisfied  disloyal Customer   29  Personal Travel       Eco
#
#         Flight Distance  Departure/Arrival time convenient  Online support  \
# ...

# %%
# Somme des personnes satisfaites par classe 

satisfait_group = satisfait[['Class']].value_counts()
satisfait_group
# Out:
# Class
# Business    44095
# Eco         22973
# Eco Plus     4019
# Name: count, dtype: int64

# %%
# Calcul du pourcentage des personnes satisfaites

taux_satisfait_group = (satisfait_group/71087)*100
taux_satisfait_group = taux_satisfait_group.apply(lambda x: f'{x: .2f}%')
taux_satisfait_group
# Out:
# Class
# Business     62.03%
# Eco          32.32%
# Eco Plus      5.65%
# Name: count, dtype: object

# %%
# selection des personnes non-satisfaites 

pas_satisfait = travel[travel['satisfaction'] == 'dissatisfied']
pas_satisfait
# Out:
#         satisfaction      Customer Type  Age   Type of Travel     Class  \
# 795     dissatisfied     Loyal Customer   48  Personal Travel  Eco Plus
# 799     dissatisfied     Loyal Customer   30  Personal Travel       Eco
# 803     dissatisfied     Loyal Customer   19  Personal Travel       Eco
# 804     dissatisfied     Loyal Customer   13  Personal Travel       Eco
# 805     dissatisfied     Loyal Customer   31  Personal Travel       Eco
# ...              ...                ...  ...              ...       ...
# 129860  dissatisfied  disloyal Customer   43  Personal Travel       Eco
# 129876  dissatisfied  disloyal Customer   63  Personal Travel  Business
# 129877  dissatisfied  disloyal Customer   69  Personal Travel       Eco
# 129878  dissatisfied  disloyal Customer   66  Personal Travel       Eco
# 129879  dissatisfied  disloyal Customer   38  Personal Travel       Eco
#
#         Flight Distance  Departure/Arrival time convenient  Online support  \
# ...

# %%
# Somme des personnes pas-satisfaites par group

pas_satisfait_group = pas_satisfait['Class'].value_counts().reset_index()
pas_satisfait_group
# Out:
#       Class  count
# 0       Eco  35336
# 1  Business  18065
# 2  Eco Plus   5392

# %%
# Calcul du pourcentage des personnes pas-satisfaites

taux_pas_satisfait_group = (pas_satisfait_group/58793)*100
taux_pas_satisfait_group = taux_pas_satisfait_group.apply(lambda x: f'{x:.2f}%')
taux_pas_satisfait_group.sort_values()
# Out:
# Class
# Business    30.73%
# Eco         60.10%
# Eco Plus     9.17%
# Name: count, dtype: object

# %%
# représentation Graphique des deux catégories, satisfait et pas satisfait
# Représentation graphique des passagers satisfaits 

couleur = ['green','purple','red']
graph_satisfait = satisfait_group.plot(kind='bar', title= 'Représentation des passagers satisfaits', xlabel='Différentes Classes', color= couleur)

graph_satisfait
# Out:
# <Axes: title={'center': 'Représentation des passagers satisfaits'}, xlabel='Différentes Classes'>

# %%
# Représentation graphique des passagers pas satisfaits 

couleur = ['green','purple','red']

graph_pas_satisfait = pas_satisfait_group.plot(kind='bar', title= 'Représentation des passagers non satisfaits',xlabel= 'Différentes_Classes', color = couleur, )

graph_pas_satisfait
# Out:
# <Axes: title={'center': 'Représentation des passagers non satisfaits'}, xlabel='Différentes_Classes'>

# %% [markdown]
# ### Calculer le nombre total des voyageurs par tranche d'âge (_Les tranches d'âges vont de **0 à 20 ans**_), ensuite faire une représentation graphiques

# %%
# Description de la colonne Age

tranche_âge = travel['Age'].describe()
tranche_âge
# Out:
# count    129880.000000
# mean         39.427957
# std          15.119360
# min           7.000000
# 25%          27.000000
# 50%          40.000000
# 75%          51.000000
# max          85.000000
# Name: Age, dtype: float64

# %%
# Nous allons catégoriser les tranches par des catégories sociales.
# Nous ajoutons la colonne 'Catégorie_Sociale' dans le Dataframe.

import numpy as np
travel["catégorie_sociale"] = np.nan
travel.columns
# Out:
# Index(['satisfaction', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Departure/Arrival time convenient',
#        'Online support', 'Baggage handling', 'Checkin service',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'catégorie_sociale'],
#       dtype='object')

# %%
travel["catégorie_sociale"][(travel['Age'] >= 0) & (travel['Age'] < 12)] = "Enfant"
travel["catégorie_sociale"][(travel['Age'] >= 13) & (travel['Age'] < 19)] = "Adolescent"
travel["catégorie_sociale"][(travel['Age'] >= 19) & (travel['Age'] < 35)] = "Jeune"
travel["catégorie_sociale"][(travel['Age'] >= 35) & (travel['Age'] < 55)] = "Adulte"
travel["catégorie_sociale"][(travel['Age'] >55)] = "Agée"
# Out:
# C:\Users\rodri\AppData\Local\Temp\ipykernel_22772\2344202693.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   travel["catégorie_sociale"][(travel['Age'] >= 0) & (travel['Age'] < 12)] = "Enfant"
# ...

# %%
# Nouveau Dataframe

travel
# Out:
#         satisfaction      Customer Type  Age   Type of Travel     Class  \
# 0          satisfied     Loyal Customer   65  Personal Travel       Eco
# 1          satisfied     Loyal Customer   47  Personal Travel  Business
# 2          satisfied     Loyal Customer   15  Personal Travel       Eco
# 3          satisfied     Loyal Customer   60  Personal Travel       Eco
# 4          satisfied     Loyal Customer   70  Personal Travel       Eco
# ...              ...                ...  ...              ...       ...
# 129875     satisfied  disloyal Customer   29  Personal Travel       Eco
# 129876  dissatisfied  disloyal Customer   63  Personal Travel  Business
# 129877  dissatisfied  disloyal Customer   69  Personal Travel       Eco
# 129878  dissatisfied  disloyal Customer   66  Personal Travel       Eco
# 129879  dissatisfied  disloyal Customer   38  Personal Travel       Eco
#
#         Flight Distance  Departure/Arrival time convenient  Online support  \
# ...

# %% [markdown]
# ### Calculer la somme des voyageurs par catégorie_sociale (**Enfant, Adolescent,Jeune, Adulte, Âgée**), et faire un  graphique.

# %%
# Selection des voyageurs dans la classe Eco  

age_Eco = travel[travel['Class'] == 'Eco']
age_Eco
# Out:
#         satisfaction      Customer Type  Age   Type of Travel Class  \
# 0          satisfied     Loyal Customer   65  Personal Travel   Eco
# 2          satisfied     Loyal Customer   15  Personal Travel   Eco
# 3          satisfied     Loyal Customer   60  Personal Travel   Eco
# 4          satisfied     Loyal Customer   70  Personal Travel   Eco
# 5          satisfied     Loyal Customer   30  Personal Travel   Eco
# ...              ...                ...  ...              ...   ...
# 129874     satisfied  disloyal Customer   11  Personal Travel   Eco
# 129875     satisfied  disloyal Customer   29  Personal Travel   Eco
# 129877  dissatisfied  disloyal Customer   69  Personal Travel   Eco
# 129878  dissatisfied  disloyal Customer   66  Personal Travel   Eco
# 129879  dissatisfied  disloyal Customer   38  Personal Travel   Eco
#
#         Flight Distance  Departure/Arrival time convenient  Online support  \
# ...

# %%
# Selection des voyageurs dans la classe Eco  

age_Eco_plus = travel[travel['Class'] == 'Eco Plus']
age_Eco_plus
# Out:
#         satisfaction      Customer Type  Age   Type of Travel     Class  \
# 24         satisfied     Loyal Customer   16  Personal Travel  Eco Plus
# 30         satisfied     Loyal Customer   62  Personal Travel  Eco Plus
# 45         satisfied     Loyal Customer   38  Personal Travel  Eco Plus
# 59         satisfied     Loyal Customer   37  Personal Travel  Eco Plus
# 69         satisfied     Loyal Customer   49  Personal Travel  Eco Plus
# ...              ...                ...  ...              ...       ...
# 129680  dissatisfied  disloyal Customer   17  Personal Travel  Eco Plus
# 129695  dissatisfied  disloyal Customer   12  Personal Travel  Eco Plus
# 129732  dissatisfied  disloyal Customer   54  Personal Travel  Eco Plus
# 129749  dissatisfied  disloyal Customer   33  Personal Travel  Eco Plus
# 129777     satisfied     Loyal Customer   13  Personal Travel  Eco Plus
#
#         Flight Distance  Departure/Arrival time convenient  Online support  \
# ...

# %%
# Selection des voyageurs dans la classe Eco  

age_Business = travel[travel['Class'] == 'Business']
age_Business
# Out:
#         satisfaction      Customer Type  Age   Type of Travel     Class  \
# 1          satisfied     Loyal Customer   47  Personal Travel  Business
# 8          satisfied     Loyal Customer   56  Personal Travel  Business
# 17         satisfied     Loyal Customer   52  Personal Travel  Business
# 23         satisfied     Loyal Customer   53  Personal Travel  Business
# 48         satisfied     Loyal Customer   31  Personal Travel  Business
# ...              ...                ...  ...              ...       ...
# 129844  dissatisfied  disloyal Customer   70  Personal Travel  Business
# 129847  dissatisfied  disloyal Customer   20  Personal Travel  Business
# 129853  dissatisfied  disloyal Customer   14  Personal Travel  Business
# 129856  dissatisfied  disloyal Customer   53  Personal Travel  Business
# 129876  dissatisfied  disloyal Customer   63  Personal Travel  Business
#
#         Flight Distance  Departure/Arrival time convenient  Online support  \
# ...

# %%
# Somme des personnes de la classe Eco

sum_age_eco = age_Eco['catégorie_sociale'].value_counts().reset_index()
sum_age_eco
# Out:
#   catégorie_sociale  count
# 0            Adulte  20255
# 1             Jeune  18989
# 2              Agée  10252
# 3        Adolescent   4394
# 4            Enfant   3000

# %%
# Somme des personnes de la classe Eco Plus

sum_age_Eco_plus = age_Eco_plus['catégorie_sociale'].value_counts().reset_index()
sum_age_Eco_plus
# Out:
#   catégorie_sociale  count
# 0            Adulte   3437
# 1             Jeune   2886
# 2              Agée   1767
# 3        Adolescent    621
# 4            Enfant    463

# %%
# Somme des personnes de la classe Eco Plus

sum_age_Business = age_Business['catégorie_sociale'].value_counts().reset_index()
sum_age_Business
# Out:
#   catégorie_sociale  count
# 0            Adulte  33223
# 1             Jeune  16402
# 2              Agée   9260
# 3        Adolescent   1261
# 4            Enfant    537

# %%
# Liste des catégories_Sociales uniques
# Nous onstatons qu'il y'a des valeurs manquantes, que nous allons supprimer
x = travel['catégorie_sociale'].unique()
x
# Out:
# array(['Agée', 'Adulte', 'Adolescent', 'Jeune', 'Enfant', nan],
#       dtype=object)

# %%
# Suppression de la valeur "nan"

drop_x = travel['catégorie_sociale'].dropna()

# %%
# Liste définitive des catégories sociales

col_cat = drop_x.unique()
col_cat
# Out:
# array(['Agée', 'Adulte', 'Adolescent', 'Jeune', 'Enfant'], dtype=object)

# %% [markdown]
# ### Représentation Graphique

# %%
import matplotlib_inline

import waterfall_chart

graph_Eco = waterfall_chart.plot(col_cat, sum_age_eco, Title= "Clients de la classe Eco")
# Out:
# c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\waterfall_chart.py:84: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '#29EA38' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   trans.loc[trans['positive'] == 1, 'color'] = green_color
# c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\waterfall_chart.py:141: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y = y_height[loop] + row['amount']
# ...

# %%
travel[].plot(kind='')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 sum_age_eco.plot(kind='hexbin')
#
# File c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_core.py:977, in PlotAccessor.__call__(self, *args, **kwargs)
#     975         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     976     else:
# --> 977         raise ValueError(f"plot kind {kind} can only be used for data frames")
#     978 elif kind in self._series_kinds:
#     979     if isinstance(data, ABCDataFrame):
#
# ValueError: plot kind hexbin can only be used for data frames

# %%
import matplotlib_inline

import waterfall_chart

graph_Eco_Plus = waterfall_chart.plot(col_cat, sum_age_Eco_plus, Title= "Clients de la classe Eco Plus")
# Out:
# c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\waterfall_chart.py:84: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '#29EA38' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   trans.loc[trans['positive'] == 1, 'color'] = green_color
# c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\waterfall_chart.py:141: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y = y_height[loop] + row['amount']
# ...

# %%
import matplotlib_inline

import waterfall_chart

graph_Business = waterfall_chart.plot(col_cat, sum_age_Business, Title= "Clients de la classe Business")
# Out:
# c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\waterfall_chart.py:84: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '#29EA38' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   trans.loc[trans['positive'] == 1, 'color'] = green_color
# c:\Users\rodri\AppData\Local\Programs\Python\Python312\Lib\site-packages\waterfall_chart.py:141: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y = y_height[loop] + row['amount']
# ...

# %% [markdown]
# ### Quelques calculs supplémentaire :
#
# - Calculer la somme des **Bagages** ;
# - Calculer la somme et la moyenne des **demandes d'aides** ;
# - Calculer la somme  des **Services de vérifications** ;
# - Déterminer **Le plus long et plus court voyage** tout en indicant __l'heure de départ et l'heure d'arrivée__.
# (_Si Possible les transformer en Heures, car elles sont en minutes_)

# %%
# Calcul du total des bagages par classe 

total_bagages = travel[['Class','Baggage handling']].groupby('Class').sum()
total_bagages
# Out:
#           Baggage handling
# Class
# Business            239541
# Eco                 207903
# Eco Plus             32550

# %%
# Calcul de la somme et moyenne des aides demandées

sum_aide = travel[['Class','Online support']].groupby('Class').sum()
mean_aide = travel[['Class','Online support']].groupby('Class').mean()
sum_aide
# Out:
#           Online support
# Class
# Business          234397
# Eco               191768
# Eco Plus           30974

# %%
mean_aide
# Out:
#           Online support
# Class
# Business        3.770866
# Eco             3.288823
# Eco Plus        3.291255

# %%
# Déterminons le plus long  voyage

max_travel = travel['Flight Distance'].max()
max_travel
# Out:
# 6951

# %%
travel[travel['Flight Distance'] == 6951]
# Out:
#        satisfaction      Customer Type  Age   Type of Travel     Class  \
# 49083  dissatisfied  disloyal Customer   42  Business travel  Business
#
#        Flight Distance  Departure/Arrival time convenient  Online support  \
# 49083             6951                                  2               1
#
#        Baggage handling  Checkin service  Departure Delay in Minutes  \
# 49083                 5                1                           1
#
#        Arrival Delay in Minutes catégorie_sociale
# 49083                      25.0            Adulte

# %%
# Déterminons le plus court voyage

min_travel = travel['Flight Distance'].min()
min_travel
# Out:
# 50

# %%
travel[travel['Flight Distance'] == 50]
# Out:
#         satisfaction   Customer Type  Age   Type of Travel     Class  \
# 760        satisfied  Loyal Customer   53  Personal Travel       Eco
# 859        satisfied  Loyal Customer   65  Personal Travel       Eco
# 1403       satisfied  Loyal Customer   47  Personal Travel       Eco
# 1652       satisfied  Loyal Customer   55  Personal Travel  Eco Plus
# 11913      satisfied  Loyal Customer   59  Personal Travel       Eco
# 12848      satisfied  Loyal Customer   66  Personal Travel       Eco
# 16197      satisfied  Loyal Customer   63  Personal Travel       Eco
# 30815   dissatisfied  Loyal Customer   54  Personal Travel  Eco Plus
# 35548   dissatisfied  Loyal Customer   60  Personal Travel       Eco
# 65089      satisfied  Loyal Customer   46  Business travel  Business
# 66546   dissatisfied  Loyal Customer   65  Business travel       Eco
# 71215   dissatisfied  Loyal Customer   53  Business travel       Eco
# 89175      satisfied  Loyal Customer   57  Business travel  Business
# ...
